# %% [markdown]
# # ProfileReport - easy way of data exploration

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Ut-S5ImLBKo3DMJe-vloHfrwbpr3xyhA)

# %%
# !pip install -U pandas-profiling
# Out:
# ...
#      |████████████████████████████████| 266kB 4.3MB/s
# ...
#      |████████████████████████████████| 61kB 5.5MB/s
# ...
#      |████████████████████████████████| 3.1MB 11.9MB/s
# ...
#      |████████████████████████████████| 604kB 25.6MB/s
# ...
#      |████████████████████████████████| 71kB 6.6MB/s
# ...
#      |████████████████████████████████| 71kB 6.7MB/s
# ...
#      |████████████████████████████████| 296kB 40.5MB/s
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-cp36-none-any.whl size=27084 sha256=72b46ba6176bdd4a8558cdd519ffc5bac518a191bde68caf43fe64ca2930bc74
#   Stored in directory: /root/.cache/pip/wheels/43/07/ac/7c5a9d708d65247ac1f94066cf1db075540b85716c30255459
# ...
#   Created wheel for imagehash: filename=ImageHash-4.1.0-py2.py3-none-any.whl size=291990 sha256=f1bbcc44f74ce1020dcd5dae3474ed16ea86ae5d7c4678b5e8d159cf0077d73a
#   Stored in directory: /root/.cache/pip/wheels/07/1c/dc/6831446f09feb8cc199ec73a0f2f0703253f6ae013a22f4be9
# Successfully built htmlmin imagehash
# ...

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/titanic_train.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title='Report of the dataset', explorative=True)
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile.to_file(output_file='output.html')
